# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df1=df[['PassengerId','Name','Sex','Age','Ticket','Embarked']]

# %%
df1
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male   NaN
# 417         1309                      Peter, Master. Michael J    male   NaN
#
#                  Ticket Embarked
# ...

# %%
df1.head()
# Out:
#    PassengerId                                          Name     Sex   Age  \
# 0          892                              Kelly, Mr. James    male  34.5
# 1          893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2          894                     Myles, Mr. Thomas Francis    male  62.0
# 3          895                              Wirz, Mr. Albert    male  27.0
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
#
#     Ticket Embarked
# 0   330911        Q
# 1   363272        S
# 2   240276        Q
# 3   315154        S
# 4  3101298        S

# %%
df1.shape
# Out:
# (418, 6)

# %%
p_table=pd.pivot_table(data=df, index=['Name','Sex','Ticket','PassengerId'])

# %%
p_table
# Out:
#                                                                                     Age  \
# Name                                          Sex    Ticket           PassengerId
# Abbott, Master. Eugene Joseph                 male   C.A. 2673        1284         13.0
# Abelseth, Miss. Karen Marie                   female 348125           1237         16.0
# Abelseth, Mr. Olaus Jorgensen                 male   348122           949          25.0
# Abrahamsson, Mr. Abraham August Johannes      male   SOTON/O2 3101284 1143         20.0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)     female 2657             900          18.0
# ...                                                                                 ...
# de Brito, Mr. Jose Joaquim                    male   244360           1228         32.0
# de Messemaeker, Mr. Guillaume Joseph          male   345572           1152         36.5
# del Carlo, Mrs. Sebastiano (Argenia Genovesi) female SC/PARIS 2167    907          24.0
# ...

# %%
p_table.head()
# Out:
#                                                                                 Age  \
# Name                                      Sex    Ticket           PassengerId
# Abbott, Master. Eugene Joseph             male   C.A. 2673        1284         13.0
# Abelseth, Miss. Karen Marie               female 348125           1237         16.0
# Abelseth, Mr. Olaus Jorgensen             male   348122           949          25.0
# Abrahamsson, Mr. Abraham August Johannes  male   SOTON/O2 3101284 1143         20.0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu) female 2657             900          18.0
#
#                                                                                   Fare  \
# Name                                      Sex    Ticket           PassengerId
# Abbott, Master. Eugene Joseph             male   C.A. 2673        1284         20.2500
# Abelseth, Miss. Karen Marie               female 348125           1237          7.6500
# ...

# %%
p_table.shape
# Out:
# (418, 5)
